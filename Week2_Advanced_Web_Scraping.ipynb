# %% [markdown]
# # Software Coaching for Python
# # Week 2: Advanced Web Scraping

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %%
from google.colab import drive

drive.mount('/content/drive')
path = "/content/drive/Shared drives/PythonCoaching_2023Summer"
my_folder = "ljw33083418"     # *** REPLACE WITH YOUR FOLDER NAME ***
outcome_folder = f"{path}/{my_folder}/outcome"
# Out:
# Mounted at /content/drive

# %%
! pip install --user --upgrade requests bs4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 1.2 MB/s eta 0:00:00
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting pandas
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 69.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=31327f4dedca6487a123f7669d3309a34f6ad25a515b83c903ecd95963fd0dc9
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: tzdata, requests, pandas, bs4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed bs4-0.0.1 pandas-2.0.3 requests-2.31.0 tzdata-2023.3

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Handle pagination

# %% [markdown]
# https://fivethirtyeight.com/features/

# %%
urls = ["https://fivethirtyeight.com/features/"]

for i in range(2, 101):     # The range(2, 101) generates a list of integers from 2 to 100.
    url = f"https://fivethirtyeight.com/features/page/{i}/"
    urls.append(url)

urls
# Out:
# ['https://fivethirtyeight.com/features/',
#  'https://fivethirtyeight.com/features/page/2/',
#  'https://fivethirtyeight.com/features/page/3/',
#  'https://fivethirtyeight.com/features/page/4/',
#  'https://fivethirtyeight.com/features/page/5/',
#  'https://fivethirtyeight.com/features/page/6/',
#  'https://fivethirtyeight.com/features/page/7/',
#  'https://fivethirtyeight.com/features/page/8/',
#  'https://fivethirtyeight.com/features/page/9/',
#  'https://fivethirtyeight.com/features/page/10/',
#  'https://fivethirtyeight.com/features/page/11/',
#  'https://fivethirtyeight.com/features/page/12/',
#  'https://fivethirtyeight.com/features/page/13/',
#  'https://fivethirtyeight.com/features/page/14/',
#  'https://fivethirtyeight.com/features/page/15/',
#  'https://fivethirtyeight.com/features/page/16/',
#  'https://fivethirtyeight.com/features/page/17/',
#  'https://fivethirtyeight.com/features/page/18/',
#  'https://fivethirtyeight.com/features/page/19/',
#  'https://fivethirtyeight.com/features/page/20/',
#  'https://fivethirtyeight.com/features/page/21/',
#  'https://fivethirtyeight.com/features/page/22/',
#  'https://fivethirtyeight.com/features/page/23/',
#  'https://fivethirtyeight.com/features/page/24/',
#  'https://fivethirtyeight.com/features/page/25/',
#  'https://fivethirtyeight.com/features/page/26/',
#  'https://fivethirtyeight.com/features/page/27/',
#  'https://fivethirtyeight.com/features/page/28/',
#  'https://fivethirtyeight.com/features/page/29/',
#  'https://fivethirtyeight.com/features/page/30/',
#  'https://fivethirtyeight.com/features/page/31/',
#  'https://fivethirtyeight.com/features/page/32/',
#  'https://fivethirtyeight.com/features/page/33/',
#  'https://fivethirtyeight.com/features/page/34/',
#  'https://fivethirtyeight.com/features/page/35/',
#  'https://fivethirtyeight.com/features/page/36/',
#  'https://fivethirtyeight.com/features/page/37/',
#  'https://fivethirtyeight.com/features/page/38/',
#  'https://fivethirtyeight.com/features/page/39/',
#  'https://fivethirtyeight.com/features/page/40/',
#  'https://fivethirtyeight.com/features/page/41/',
#  'https://fivethirtyeight.com/features/page/42/',
#  'https://fivethirtyeight.com/features/page/43/',
#  'https://fivethirtyeight.com/features/page/44/',
#  'https://fivethirtyeight.com/features/page/45/',
#  'https://fivethirtyeight.com/features/page/46/',
#  'https://fivethirtyeight.com/features/page/47/',
#  'https://fivethirtyeight.com/features/page/48/',
#  'https://fivethirtyeight.com/features/page/49/',
#  'https://fivethirtyeight.com/features/page/50/',
#  'https://fivethirtyeight.com/features/page/51/',
#  'https://fivethirtyeight.com/features/page/52/',
#  'https://fivethirtyeight.com/features/page/53/',
#  'https://fivethirtyeight.com/features/page/54/',
#  'https://fivethirtyeight.com/features/page/55/',
#  'https://fivethirtyeight.com/features/page/56/',
#  'https://fivethirtyeight.com/features/page/57/',
#  'https://fivethirtyeight.com/features/page/58/',
#  'https://fivethirtyeight.com/features/page/59/',
#  'https://fivethirtyeight.com/features/page/60/',
#  'https://fivethirtyeight.com/features/page/61/',
#  'https://fivethirtyeight.com/features/page/62/',
#  'https://fivethirtyeight.com/features/page/63/',
#  'https://fivethirtyeight.com/features/page/64/',
#  'https://fivethirtyeight.com/features/page/65/',
#  'https://fivethirtyeight.com/features/page/66/',
#  'https://fivethirtyeight.com/features/page/67/',
#  'https://fivethirtyeight.com/features/page/68/',
#  'https://fivethirtyeight.com/features/page/69/',
#  'https://fivethirtyeight.com/features/page/70/',
#  'https://fivethirtyeight.com/features/page/71/',
#  'https://fivethirtyeight.com/features/page/72/',
#  'https://fivethirtyeight.com/features/page/73/',
#  'https://fivethirtyeight.com/features/page/74/',
#  'https://fivethirtyeight.com/features/page/75/',
#  'https://fivethirtyeight.com/features/page/76/',
#  'https://fivethirtyeight.com/features/page/77/',
#  'https://fivethirtyeight.com/features/page/78/',
#  'https://fivethirtyeight.com/features/page/79/',
#  'https://fivethirtyeight.com/features/page/80/',
#  'https://fivethirtyeight.com/features/page/81/',
#  'https://fivethirtyeight.com/features/page/82/',
#  'https://fivethirtyeight.com/features/page/83/',
#  'https://fivethirtyeight.com/features/page/84/',
#  'https://fivethirtyeight.com/features/page/85/',
#  'https://fivethirtyeight.com/features/page/86/',
#  'https://fivethirtyeight.com/features/page/87/',
#  'https://fivethirtyeight.com/features/page/88/',
#  'https://fivethirtyeight.com/features/page/89/',
#  'https://fivethirtyeight.com/features/page/90/',
#  'https://fivethirtyeight.com/features/page/91/',
#  'https://fivethirtyeight.com/features/page/92/',
#  'https://fivethirtyeight.com/features/page/93/',
#  'https://fivethirtyeight.com/features/page/94/',
#  'https://fivethirtyeight.com/features/page/95/',
#  'https://fivethirtyeight.com/features/page/96/',
#  'https://fivethirtyeight.com/features/page/97/',
#  'https://fivethirtyeight.com/features/page/98/',
#  'https://fivethirtyeight.com/features/page/99/',
#  'https://fivethirtyeight.com/features/page/100/']

# %% [markdown]
# Try to get all of the URLs of the target webpages first before trying to get the contents from those webpages. At this point, it is important to find a rule for creating the URLs.

# %%
for url in urls:
    print(url)              # Do whatever you want with each web page.
# Out:
# https://fivethirtyeight.com/features/
# https://fivethirtyeight.com/features/page/2/
# https://fivethirtyeight.com/features/page/3/
# https://fivethirtyeight.com/features/page/4/
# https://fivethirtyeight.com/features/page/5/
# https://fivethirtyeight.com/features/page/6/
# https://fivethirtyeight.com/features/page/7/
# https://fivethirtyeight.com/features/page/8/
# https://fivethirtyeight.com/features/page/9/
# https://fivethirtyeight.com/features/page/85/
# https://fivethirtyeight.com/features/page/86/
# https://fivethirtyeight.com/features/page/87/
# https://fivethirtyeight.com/features/page/88/
# https://fivethirtyeight.com/features/page/89/
# https://fivethirtyeight.com/features/page/90/
# https://fivethirtyeight.com/features/page/91/
# https://fivethirtyeight.com/features/page/92/
# https://fivethirtyeight.com/features/page/93/
# https://fivethirtyeight.com/features/page/94/
# https://fivethirtyeight.com/features/page/95/
# https://fivethirtyeight.com/features/page/96/
# https://fivethirtyeight.com/features/page/97/
# https://fivethirtyeight.com/features/page/98/
# https://fivethirtyeight.com/features/page/99/
# https://fivethirtyeight.com/features/page/100/

# %% [markdown]
# ## Write & read an HTML file

# %%
url = "https://fivethirtyeight.com/features/argentina-and-france-lived-up-to-the-world-cup-finals-hype-and-then-transcended-it/"
r = requests.get(url)

# %%
url[len("https://fivethirtyeight.com/features/"):-1]
# Out:
# 'argentina-and-france-lived-up-to-the-world-cup-finals-hype-and-then-transcended-it'

# %%
file_name = url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
file_name
# Out:
# 'argentina-and-france-lived-up-to-the-world-cup-finals-hype-and-then-transcended-it.html'

# %%
with open(f"{outcome_folder}/{file_name}", "w+b") as fw: # html 파일도 binary로 쓰고 읽어야함
    fw.write(r.content)

# %%
with open(f"{outcome_folder}/{file_name}", "r+b") as fr:
    soup = BeautifulSoup(fr.read(), "html.parser")

    print(soup.title.text)          # Do whatever you want with the saved web page.
# Out:
# Argentina And France Lived Up To The World Cup Final’s Hype — And Then Transcended It | FiveThirtyEight

# %% [markdown]
# ## Automate the process of saving all articles on the Features list

# %%
urls = ["https://fivethirtyeight.com/features/"]

for i in range(2, 11):     # The range(2, 11) generates a list of integers from 2 to 10.
    url = f"https://fivethirtyeight.com/features/page/{i}/"
    urls.append(url)

urls
# Out:
# ['https://fivethirtyeight.com/features/',
#  'https://fivethirtyeight.com/features/page/2/',
#  'https://fivethirtyeight.com/features/page/3/',
#  'https://fivethirtyeight.com/features/page/4/',
#  'https://fivethirtyeight.com/features/page/5/',
#  'https://fivethirtyeight.com/features/page/6/',
#  'https://fivethirtyeight.com/features/page/7/',
#  'https://fivethirtyeight.com/features/page/8/',
#  'https://fivethirtyeight.com/features/page/9/',
#  'https://fivethirtyeight.com/features/page/10/']

# %%
len(urls)
# Out:
# 10

# %%
import os

if not os.path.isdir(f"{outcome_folder}/HTMLs"):
    os.mkdir(f"{outcome_folder}/HTMLs")

# %%
import time     # Necessary for the sleep function.

# %%
for url in urls:
    print(url)

    ####################################################
    # Get the content of a page
    ####################################################
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")

    ####################################################
    # Get the list of articles
    ####################################################
    h2_list = soup.find_all("h2", {"class": "article-title entry-title"})

    for h2 in h2_list:
        ####################################################
        # Find the anchor tag
        ####################################################
        a = h2.find("a")

        ####################################################
        # Extract the title & URL of an article
        ####################################################
        title = a.text
        article_url = a["href"]

        ####################################################
        # Fetch the content and save it as an HTML file
        ####################################################
        print("- " + article_url + ": processing...")

        r2 = requests.get(article_url)

        if "/features/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
        elif "/videos/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/videos/"):-1] + ".html"
        elif "/methodology/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/methodology/"):-1] + ".html"
        elif "/live-blog/" in article_url:
          file_name = article_url[len("https://fivethirtyeight.com/live-blog/"):-1] + ".html"
        else:
          assert 0 == 1, "Unknown article url pattern!"

        with open(f"{outcome_folder}/HTMLs/{file_name}", "w+b") as fw:
            fw.write(r2.content)

        print("- " + file_name + ": saved.")

        ####################################################
        # Sleep for a second to not overload the web site
        ####################################################
        time.sleep(1)

    print()
# Out:
# https://fivethirtyeight.com/features/
# - https://fivethirtyeight.com/features/house-retirements-2024/: processing...
# - house-retirements-2024.html: saved.
# - https://fivethirtyeight.com/features/2024-dropout-draft/: processing...
# - 2024-dropout-draft.html: saved.
# - https://fivethirtyeight.com/features/americans-increasingly-against-abortion-limits/: processing...
# - americans-increasingly-against-abortion-limits.html: saved.
# - https://fivethirtyeight.com/videos/who-would-win-if-trump-wasnt-in-the-gop-primary/: processing...
# - who-would-win-if-trump-wasnt-in-the-gop-primary.html: saved.
# - https://fivethirtyeight.com/features/republican-august-debate-qualifications/: processing...
# - republican-august-debate-qualifications.html: saved.
# - https://fivethirtyeight.com/features/16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier/: processing...
# - 16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier.html: saved.
# - https://fivethirtyeight.com/videos/whats-the-deal-with-long-shot-presidential-candidates/: processing...
# - whats-the-deal-with-long-shot-presidential-candidates.html: saved.
# - https://fivethirtyeight.com/features/tell-us-what-the-resumption-of-student-loan-payments-means-for-you/: processing...
# - tell-us-what-the-resumption-of-student-loan-payments-means-for-you.html: saved.
# - https://fivethirtyeight.com/features/2024-early-state-visits-republicans/: processing...
# - 2024-early-state-visits-republicans.html: saved.
#
# https://fivethirtyeight.com/features/page/2/
# - https://fivethirtyeight.com/features/second-quarter-fundraising-2024-presidential-race/: processing...
# - second-quarter-fundraising-2024-presidential-race.html: saved.
# - https://fivethirtyeight.com/features/alabama-redistricting-congressional-map-black-voters/: processing...
# - alabama-redistricting-congressional-map-black-voters.html: saved.
# - https://fivethirtyeight.com/videos/what-money-can-and-cant-buy-in-the-2024-primary/: processing...
# - what-money-can-and-cant-buy-in-the-2024-primary.html: saved.
# - https://fivethirtyeight.com/features/republican-debate-qualification-fundraising-tactics/: processing...
# - republican-debate-qualification-fundraising-tactics.html: saved.
# - https://fivethirtyeight.com/features/pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse/: processing...
# - pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse.html: saved.
# - https://fivethirtyeight.com/features/third-party-candidate-spoiler-trump-biden/: processing...
# - third-party-candidate-spoiler-trump-biden.html: saved.
# - https://fivethirtyeight.com/features/which-2024-candidates-had-the-best-and-worst-campaign-launches/: processing...
# - which-2024-candidates-had-the-best-and-worst-campaign-launches.html: saved.
# - https://fivethirtyeight.com/features/biden-says-the-economys-doing-great-lots-of-his-own-voters-dont-believe-him/: processing...
# - how-much-money-can-you-pull-out-of-a-hat.html: saved.
# - https://fivethirtyeight.com/videos/is-the-eurovision-song-contest-rigged/: processing...
# - is-the-eurovision-song-contest-rigged.html: saved.
# - https://fivethirtyeight.com/features/some-evangelical-voters-arent-sold-on-trump-will-that-help-desantis/: processing...
# - some-evangelical-voters-arent-sold-on-trump-will-that-help-desantis.html: saved.
# - https://fivethirtyeight.com/features/republican-states-expanding-gun-rights-mass-shootings/: processing...
# - republican-states-expanding-gun-rights-mass-shootings.html: saved.
# - https://fivethirtyeight.com/videos/which-news-outlets-do-americans-trust/: processing...
# - which-news-outlets-do-americans-trust.html: saved.

# %% [markdown]
# ## Extract information from all HTML files & save it in a CSV file

# %%
os.listdir(f"{outcome_folder}/HTMLs")
# Out:
# ['house-retirements-2024.html',
#  '2024-dropout-draft.html',
#  'americans-increasingly-against-abortion-limits.html',
#  'who-would-win-if-trump-wasnt-in-the-gop-primary.html',
#  'republican-august-debate-qualifications.html',
#  '16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier.html',
#  'whats-the-deal-with-long-shot-presidential-candidates.html',
#  'tell-us-what-the-resumption-of-student-loan-payments-means-for-you.html',
#  '2024-early-state-visits-republicans.html',
#  'second-quarter-fundraising-2024-presidential-race.html',
#  'alabama-redistricting-congressional-map-black-voters.html',
#  'what-money-can-and-cant-buy-in-the-2024-primary.html',
#  'republican-debate-qualification-fundraising-tactics.html',
#  'pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse.html',
#  'third-party-candidate-spoiler-trump-biden.html',
#  'which-2024-candidates-had-the-best-and-worst-campaign-launches.html',
#  'biden-says-the-economys-doing-great-lots-of-his-own-voters-dont-believe-him.html',
#  'why-americans-arent-feeling-bidenomics.html',
#  'vivek-ramaswamy-2024-republican-primary.html',
#  'the-supreme-court-had-a-few-surprises-this-year-that-doesnt-make-it-moderate.html',
#  'extremism-mass-casualty-events-shootings.html',
#  'why-biden-probably-wont-get-a-serious-primary-challenger.html',
#  'how-impactful-was-this-supreme-court-term.html',
#  'what-happened-in-this-years-supreme-court-term.html',
#  'supreme-court-student-loan-forgiveness-biden.html',
#  'so-long-and-thanks-for-all-the-riddles.html',
#  'no-labels-is-chasing-a-fantasy.html',
#  'american-opinion-affirmative-action.html',
#  'nonreligious-americans-are-the-new-abortion-voters.html',
#  'introducing-our-brand-new-polling-averages.html',
#  'how-our-polling-averages-work.html',
#  'supreme-court-moore-harper-2024-election.html',
#  'whos-a-serious-candidate-for-the-republican-nomination-and-whos-just-dreaming.html',
#  'whats-with-rfk-jr-s-double-digit-polling.html',
#  'vulnerable-senate-democrats-vote-against-biden.html',
#  'the-final-battle-for-riddler-nation.html',
#  'will-hurd-2024-republican-primary.html',
#  'dobbs-abortion-opinion-liability-republicans.html',
#  'how-seriously-should-we-take-marianne-williamson-and-robert-f-kennedy-jr-against-biden.html',
#  'are-young-voters-staying-liberal-longer.html',
#  'what-the-polls-say-after-trumps-second-indictment.html',
#  'can-you-solve-middle-square-madness.html',
#  'francis-suarez-president-election-2024.html',
#  'abortion-trend-after-dobbs.html',
#  'why-mike-pence-is-starting-his-presidential-campaign-from-a-disadvantage.html',
#  '2024-presidential-elections-online-memes.html',
#  'whats-next-in-trumps-classified-documents-case.html',
#  'supreme-court-approval-rating-polls.html',
#  'biden-trump-indictment.html',
#  'why-the-latest-trump-indictment-looks-so-bad-for-him.html',
#  'trump-indictment-republican-primary-candidates-reaction.html',
#  'donald-trump-second-indictment-election-fallout.html',
#  'can-you-defeat-a-troll-with-your-calculator.html',
#  'supreme-court-voting-rights-redistricting-implications.html',
#  'roberts-kavanaugh-voting-rights-act-alabama.html',
#  'republican-primary-electability.html',
#  'and-then-there-were-9-gop-presidential-candidates.html',
#  'chris-christie-2024-republican-primary.html',
#  'who-is-doug-burgum-the-north-dakota-governor-running-for-president.html',
#  'mike-pence-2024-campaign.html',
#  'doug-burgum-2024-republican-primary.html',
#  'republican-debate-criteria-2024-primary.html',
#  'abortion-2024-republican-candidates.html',
#  'who-gave-up-more-in-the-debt-ceiling-negotiations-biden-or-republicans.html',
#  'can-you-calculate-the-long-shot.html',
#  'trump-polls-very-conservative-voters-2016-2024.html',
#  'biden-approval-black-hispanic-voters.html',
#  'where-the-debt-ceiling-agreement-goes-from-here.html',
#  'debt-ceiling-spending-cuts-confusing-polls.html',
#  'can-you-game-the-currency-exchange.html',
#  'debt-ceiling-default-consequences.html',
#  'whats-the-deal-with-the-fight-over-the-debt-ceiling.html',
#  'what-will-desantiss-presidential-bid-look-like.html',
#  'anti-lgbtq-laws-red-states.html',
#  'everything-you-need-to-know-about-ron-desantis.html',
#  'ron-desantis-2024-republican-presidential-announcement.html',
#  '2024-republican-presidential-primary-draft-politics-chat.html',
#  'the-gop-primary-field-is-growing-fast.html',
#  'tim-scott-presidential-announcement-2024.html',
#  'who-is-tim-scott-the-gop-candidate-whos-combating-trump-with-optimism.html',
#  'desantis-florida-conservatism-2024.html',
#  'how-much-money-can-you-pull-out-of-a-hat.html',
#  'is-the-eurovision-song-contest-rigged.html',
#  'some-evangelical-voters-arent-sold-on-trump-will-that-help-desantis.html',
#  'republican-states-expanding-gun-rights-mass-shootings.html',
#  'which-news-outlets-do-americans-trust.html']

# %%
html_files = [file for file in os.listdir(f"{outcome_folder}/HTMLs") if file.endswith(".html")]
html_files
# Out:
# ['house-retirements-2024.html',
#  '2024-dropout-draft.html',
#  'americans-increasingly-against-abortion-limits.html',
#  'who-would-win-if-trump-wasnt-in-the-gop-primary.html',
#  'republican-august-debate-qualifications.html',
#  '16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier.html',
#  'whats-the-deal-with-long-shot-presidential-candidates.html',
#  'tell-us-what-the-resumption-of-student-loan-payments-means-for-you.html',
#  '2024-early-state-visits-republicans.html',
#  'second-quarter-fundraising-2024-presidential-race.html',
#  'alabama-redistricting-congressional-map-black-voters.html',
#  'what-money-can-and-cant-buy-in-the-2024-primary.html',
#  'republican-debate-qualification-fundraising-tactics.html',
#  'pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse.html',
#  'third-party-candidate-spoiler-trump-biden.html',
#  'which-2024-candidates-had-the-best-and-worst-campaign-launches.html',
#  'biden-says-the-economys-doing-great-lots-of-his-own-voters-dont-believe-him.html',
#  'why-americans-arent-feeling-bidenomics.html',
#  'vivek-ramaswamy-2024-republican-primary.html',
#  'the-supreme-court-had-a-few-surprises-this-year-that-doesnt-make-it-moderate.html',
#  'extremism-mass-casualty-events-shootings.html',
#  'why-biden-probably-wont-get-a-serious-primary-challenger.html',
#  'how-impactful-was-this-supreme-court-term.html',
#  'what-happened-in-this-years-supreme-court-term.html',
#  'supreme-court-student-loan-forgiveness-biden.html',
#  'so-long-and-thanks-for-all-the-riddles.html',
#  'no-labels-is-chasing-a-fantasy.html',
#  'american-opinion-affirmative-action.html',
#  'nonreligious-americans-are-the-new-abortion-voters.html',
#  'introducing-our-brand-new-polling-averages.html',
#  'how-our-polling-averages-work.html',
#  'supreme-court-moore-harper-2024-election.html',
#  'whos-a-serious-candidate-for-the-republican-nomination-and-whos-just-dreaming.html',
#  'whats-with-rfk-jr-s-double-digit-polling.html',
#  'vulnerable-senate-democrats-vote-against-biden.html',
#  'the-final-battle-for-riddler-nation.html',
#  'will-hurd-2024-republican-primary.html',
#  'dobbs-abortion-opinion-liability-republicans.html',
#  'how-seriously-should-we-take-marianne-williamson-and-robert-f-kennedy-jr-against-biden.html',
#  'are-young-voters-staying-liberal-longer.html',
#  'what-the-polls-say-after-trumps-second-indictment.html',
#  'can-you-solve-middle-square-madness.html',
#  'francis-suarez-president-election-2024.html',
#  'abortion-trend-after-dobbs.html',
#  'why-mike-pence-is-starting-his-presidential-campaign-from-a-disadvantage.html',
#  '2024-presidential-elections-online-memes.html',
#  'whats-next-in-trumps-classified-documents-case.html',
#  'supreme-court-approval-rating-polls.html',
#  'biden-trump-indictment.html',
#  'why-the-latest-trump-indictment-looks-so-bad-for-him.html',
#  'trump-indictment-republican-primary-candidates-reaction.html',
#  'donald-trump-second-indictment-election-fallout.html',
#  'can-you-defeat-a-troll-with-your-calculator.html',
#  'supreme-court-voting-rights-redistricting-implications.html',
#  'roberts-kavanaugh-voting-rights-act-alabama.html',
#  'republican-primary-electability.html',
#  'and-then-there-were-9-gop-presidential-candidates.html',
#  'chris-christie-2024-republican-primary.html',
#  'who-is-doug-burgum-the-north-dakota-governor-running-for-president.html',
#  'mike-pence-2024-campaign.html',
#  'doug-burgum-2024-republican-primary.html',
#  'republican-debate-criteria-2024-primary.html',
#  'abortion-2024-republican-candidates.html',
#  'who-gave-up-more-in-the-debt-ceiling-negotiations-biden-or-republicans.html',
#  'can-you-calculate-the-long-shot.html',
#  'trump-polls-very-conservative-voters-2016-2024.html',
#  'biden-approval-black-hispanic-voters.html',
#  'where-the-debt-ceiling-agreement-goes-from-here.html',
#  'debt-ceiling-spending-cuts-confusing-polls.html',
#  'can-you-game-the-currency-exchange.html',
#  'debt-ceiling-default-consequences.html',
#  'whats-the-deal-with-the-fight-over-the-debt-ceiling.html',
#  'what-will-desantiss-presidential-bid-look-like.html',
#  'anti-lgbtq-laws-red-states.html',
#  'everything-you-need-to-know-about-ron-desantis.html',
#  'ron-desantis-2024-republican-presidential-announcement.html',
#  '2024-republican-presidential-primary-draft-politics-chat.html',
#  'the-gop-primary-field-is-growing-fast.html',
#  'tim-scott-presidential-announcement-2024.html',
#  'who-is-tim-scott-the-gop-candidate-whos-combating-trump-with-optimism.html',
#  'desantis-florida-conservatism-2024.html',
#  'how-much-money-can-you-pull-out-of-a-hat.html',
#  'is-the-eurovision-song-contest-rigged.html',
#  'some-evangelical-voters-arent-sold-on-trump-will-that-help-desantis.html',
#  'republican-states-expanding-gun-rights-mass-shootings.html',
#  'which-news-outlets-do-americans-trust.html']

# %%
len(html_files)
# Out:
# 86

# %%
with open(f"{outcome_folder}/html_metadata.csv", "w") as fw:
    ####################################################
    # Column names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")   # A tab between columns and a new line between rows

    for file_name in html_files:
        ####################################################
        # Column values starting from the second row
        ####################################################
        with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")
            article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
            article_author = soup.find("a", {"class": "author url fn"}).text

            #####################################################################
            # Remove all possible tabs, as tab is being used as column delimiter
            #####################################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")

            fw.write(f"{file_name}\t{article_title}\t{article_author}\n")
# Out:
# house-retirements-2024.html
# 2024-dropout-draft.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2ab4ac6c183b> in <cell line: 1>()
#      13             soup = BeautifulSoup(fr.read(), "html.parser")
#      14             article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
# ---> 15             article_author = soup.find("a", {"class": "author url fn"}).text
#      16
#      17             #####################################################################
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
with open(f"{outcome_folder}/html_metadata.csv", "w") as fw:
    ####################################################
    # Column names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")

    for file_name in html_files:
        if not file_name.endswith(".html"):
            continue

        ####################################################
        # Column values starting from the second row
        ####################################################
        with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")
            article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()

            ####################################################
            # No author exception handling
            ####################################################
            if soup.find("a", {"class": "author url fn"}) == None:
                article_author = ""
            else:
                article_author = soup.find("a", {"class": "author url fn"}).text

            ####################################################
            # Remove all possible tabs
            ####################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")

            fw.write(f"{file_name}\t{article_title}\t{article_author}\n")
# Out:
# house-retirements-2024.html
# 2024-dropout-draft.html
# americans-increasingly-against-abortion-limits.html
# who-would-win-if-trump-wasnt-in-the-gop-primary.html
# republican-august-debate-qualifications.html
# 16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier.html
# whats-the-deal-with-long-shot-presidential-candidates.html
# tell-us-what-the-resumption-of-student-loan-payments-means-for-you.html
# 2024-early-state-visits-republicans.html
# second-quarter-fundraising-2024-presidential-race.html
# alabama-redistricting-congressional-map-black-voters.html
# what-money-can-and-cant-buy-in-the-2024-primary.html
# republican-debate-qualification-fundraising-tactics.html
# pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse.html
# third-party-candidate-spoiler-trump-biden.html
# which-2024-candidates-had-the-best-and-worst-campaign-launches.html
# biden-says-the-economys-doing-great-lots-of-his-own-voters-dont-believe-him.html
# why-americans-arent-feeling-bidenomics.html
    ####################################################
    # Column names on the first row
    ####################################################
    fw.write("file_name\tarticle_title\tarticle_author\n")

    for file_name in html_files:
        if not file_name.endswith(".html"):
            continue

        ####################################################
        # Column values starting from the second row
        ####################################################
        with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
            print(file_name)
            soup = BeautifulSoup(fr.read(), "html.parser")

            ####################################################
            # No title exception handling
            ####################################################
            if soup.find("h1", {"class": "article-title article-title-single entry-title"}) == None:
                article_title = ""
            else:
                article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()

            ####################################################
            # No author exception handling
            ####################################################
            if soup.find("a", {"class": "author url fn"}) == None:
                article_author = ""
            else:
                article_author = soup.find("a", {"class": "author url fn"}).text

            ####################################################
            # Remove all possible tabs
            ####################################################
            article_title = article_title.replace("\t", "")
            article_aurthor = article_author.replace("\t", "")

            fw.write(f"{file_name}\t{article_title}\t{article_author}\n")
# Out:
# house-retirements-2024.html
# 2024-dropout-draft.html
# americans-increasingly-against-abortion-limits.html
# who-would-win-if-trump-wasnt-in-the-gop-primary.html
# republican-august-debate-qualifications.html
# 16-states-made-it-harder-to-vote-this-year-but-26-made-it-easier.html
# whats-the-deal-with-long-shot-presidential-candidates.html
# tell-us-what-the-resumption-of-student-loan-payments-means-for-you.html
# 2024-early-state-visits-republicans.html
# second-quarter-fundraising-2024-presidential-race.html
# alabama-redistricting-congressional-map-black-voters.html
# what-money-can-and-cant-buy-in-the-2024-primary.html
# republican-debate-qualification-fundraising-tactics.html
# pennsylvania-governor-josh-shapiro-approval-polls-i-95-bridge-collapse.html
# third-party-candidate-spoiler-trump-biden.html
# which-2024-candidates-had-the-best-and-worst-campaign-launches.html
# biden-says-the-economys-doing-great-lots-of-his-own-voters-dont-believe-him.html
# why-americans-arent-feeling-bidenomics.html
# vivek-ramaswamy-2024-republican-primary.html
# the-supreme-court-had-a-few-surprises-this-year-that-doesnt-make-it-moderate.html
# extremism-mass-casualty-events-shootings.html
# why-biden-probably-wont-get-a-serious-primary-challenger.html
# how-impactful-was-this-supreme-court-term.html
# what-happened-in-this-years-supreme-court-term.html
# supreme-court-student-loan-forgiveness-biden.html
# so-long-and-thanks-for-all-the-riddles.html
# no-labels-is-chasing-a-fantasy.html
# american-opinion-affirmative-action.html
# nonreligious-americans-are-the-new-abortion-voters.html
# introducing-our-brand-new-polling-averages.html
# how-our-polling-averages-work.html
# supreme-court-moore-harper-2024-election.html
# whos-a-serious-candidate-for-the-republican-nomination-and-whos-just-dreaming.html
# whats-with-rfk-jr-s-double-digit-polling.html
# vulnerable-senate-democrats-vote-against-biden.html
# the-final-battle-for-riddler-nation.html
# will-hurd-2024-republican-primary.html
# dobbs-abortion-opinion-liability-republicans.html
# how-seriously-should-we-take-marianne-williamson-and-robert-f-kennedy-jr-against-biden.html
# are-young-voters-staying-liberal-longer.html
# what-the-polls-say-after-trumps-second-indictment.html
# can-you-solve-middle-square-madness.html
# francis-suarez-president-election-2024.html
# abortion-trend-after-dobbs.html
# why-mike-pence-is-starting-his-presidential-campaign-from-a-disadvantage.html
# 2024-presidential-elections-online-memes.html
# whats-next-in-trumps-classified-documents-case.html
