# %% [markdown]
# # Software Coaching for Python
# # Week 4: Text Data Processing

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %%
from google.colab import drive

drive.mount('/content/drive')
path = "/content/drive/Shared drives/PythonCoaching_2023Summer"
my_folder = "ljw33083418"     # *** REPLACE WITH YOUR FOLDER NAME ***
outcome_folder = f"{path}/{my_folder}/outcome"
classdata_folder = f"{path}/classdata"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install packages

# %%
! pip install --user nltk textblob
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.0)

# %% [markdown]
# ## Basic NLP Techniques Using NLTK

# %%
text = "Some people did not think it was possible to produce a #COVID19 vaccine so quickly, but it was. Now some people say that vaccinating the world is not possible. They’re wrong. As Nelson Mandela, Madiba, said; it always seems impossible until it’s done."
text
# Out:
# 'Some people did not think it was possible to produce a #COVID19 vaccine so quickly, but it was. Now some people say that vaccinating the world is not possible. They’re wrong. As Nelson Mandela, Madiba, said; it always seems impossible until it’s done.'

# %% [markdown]
# Suppose you would like to identify sentences in a string.

# %%
text.split(".")
# Out:
# ['Some people did not think it was possible to produce a #COVID19 vaccine so quickly, but it was',
#  ' Now some people say that vaccinating the world is not possible',
#  ' They’re wrong',
#  ' As Nelson Mandela, Madiba, said; it always seems impossible until it’s done',
#  '']

# %% [markdown]
# Two problems with simply splitting a sentence with a period:
# - A sentence does not always end with a period. For example, it can also end with a question mark or an exclamation mark.
# - A period does not always mean completeness of a sentence, for emample, Ms., Dr., 3.14, etc.

# %% [markdown]
# Now suppose you would also like to identify words in a string.

# %%
text.split(" ")     # 'was.', 'possible.', 'wrong.', 'said;', 'done.'
# Out:
# ['Some',
#  'people',
#  'did',
#  'not',
#  'think',
#  'it',
#  'was',
#  'possible',
#  'to',
#  'produce',
#  'a',
#  '#COVID19',
#  'vaccine',
#  'so',
#  'quickly,',
#  'but',
#  'it',
#  'was.',
#  'Now',
#  'some',
#  'people',
#  'say',
#  'that',
#  'vaccinating',
#  'the',
#  'world',
#  'is',
#  'not',
#  'possible.',
#  'They’re',
#  'wrong.',
#  'As',
#  'Nelson',
#  'Mandela,',
#  'Madiba,',
#  'said;',
#  'it',
#  'always',
#  'seems',
#  'impossible',
#  'until',
#  'it’s',
#  'done.']

# %% [markdown]
# Splitting text with a space works generally fine except that it cannot handle punctuation characters such as comma, period, and 's.

# %% [markdown]
# ### Sentence Tokenization

# %%
import nltk

nltk.download(['punkt', 'averaged_perceptron_tagger', 'stopwords']) #back data를 다운 받아야함
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Natural Language Toolkit (NLTK): https://www.nltk.org/

# %%
sents = nltk.sent_tokenize(text)       # Tokenize text into sentences
sents
# Out:
# ['Some people did not think it was possible to produce a #COVID19 vaccine so quickly, but it was.',
#  'Now some people say that vaccinating the world is not possible.',
#  'They’re wrong.',
#  'As Nelson Mandela, Madiba, said; it always seems impossible until it’s done.']

# %%
len(sents)
# Out:
# 4

# %% [markdown]
# ### Word Tokenization

# %%
words = nltk.word_tokenize(text)        # Tokenize text into words
words
# Out:
# ['Some',
#  'people',
#  'did',
#  'not',
#  'think',
#  'it',
#  'was',
#  'possible',
#  'to',
#  'produce',
#  'a',
#  '#',
#  'COVID19',
#  'vaccine',
#  'so',
#  'quickly',
#  ',',
#  'but',
#  'it',
#  'was',
#  '.',
#  'Now',
#  'some',
#  'people',
#  'say',
#  'that',
#  'vaccinating',
#  'the',
#  'world',
#  'is',
#  'not',
#  'possible',
#  '.',
#  'They',
#  '’',
#  're',
#  'wrong',
#  '.',
#  'As',
#  'Nelson',
#  'Mandela',
#  ',',
#  'Madiba',
#  ',',
#  'said',
#  ';',
#  'it',
#  'always',
#  'seems',
#  'impossible',
#  'until',
#  'it',
#  '’',
#  's',
#  'done',
#  '.']

# %% [markdown]
# Note that each punctuation character is also treated as a token.

# %%
len(words)
# Out:
# 56

# %% [markdown]
# ### Part-of-Speech (PoS) Tagging

# %% [markdown]
# Part-of-speech tagging is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech. A simplified form of this is commonly taught to school-age children, in the identification of words as nouns, verbs, adjectives, adverbs, etc.

# %% [markdown]
# Part-of-speech tagging on Wikipedia: https://en.wikipedia.org/wiki/Part-of-speech_tagging

# %%
tagged_words = nltk.pos_tag(words)          # Tag each word with their part-of-speech tag
tagged_words
# Out:
# [('Some', 'DT'),
#  ('people', 'NNS'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('think', 'VB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('possible', 'JJ'),
#  ('to', 'TO'),
#  ('produce', 'VB'),
#  ('a', 'DT'),
#  ('#', '#'),
#  ('COVID19', 'NNP'),
#  ('vaccine', 'NN'),
#  ('so', 'RB'),
#  ('quickly', 'RB'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('.', '.'),
#  ('Now', 'RB'),
#  ('some', 'DT'),
#  ('people', 'NNS'),
#  ('say', 'VBP'),
#  ('that', 'IN'),
#  ('vaccinating', 'VBG'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('possible', 'JJ'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('wrong', 'JJ'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('Nelson', 'NNP'),
#  ('Mandela', 'NNP'),
#  (',', ','),
#  ('Madiba', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  (';', ':'),
#  ('it', 'PRP'),
#  ('always', 'RB'),
#  ('seems', 'VBZ'),
#  ('impossible', 'JJ'),
#  ('until', 'IN'),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'JJ'),
#  ('done', 'VBN'),
#  ('.', '.')]

# %% [markdown]
# Note that the argument of <b>pos_tag</b> function is a list of words, not raw text.

# %% [markdown]
# Penn Part of Speech Tags: https://cs.nyu.edu/grishman/jet/guide/PennPOS.html

# %%
[word for word, tag in tagged_words if tag in ["NN", "NNS"]]   # Noun, singular or mass; Noun, plural
# Out:
# ['people', 'vaccine', 'people', 'world']

# %%
[word for word, tag in tagged_words if tag in ["NNP", "NNPS"]]  # Proper noun, singular; Proper noun, plural
# Out:
# ['COVID19', 'Nelson', 'Mandela', 'Madiba']

# %%
[word for word, tag in tagged_words if tag.startswith("NN")]
# Out:
# ['people',
#  'COVID19',
#  'vaccine',
#  'people',
#  'world',
#  'Nelson',
#  'Mandela',
#  'Madiba']

# %%
[word for word, tag in tagged_words if tag.startswith("JJ")]
# Out:
# ['possible', 'possible', 're', 'wrong', 'impossible', 's']

# %%
[word for word, tag in tagged_words if tag.startswith("VB")]
# Out:
# ['did',
#  'think',
#  'was',
#  'produce',
#  'was',
#  'say',
#  'vaccinating',
#  'is',
#  '’',
#  'said',
#  'seems',
#  '’',
#  'done']

# %% [markdown]
# ### Stemming

# %% [markdown]
# Stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form.
#
# A computer program or subroutine that stems word may be called a stemming program, stemming algorithm, or stemmer.

# %% [markdown]
# Stemming on Wikipedia: https://en.wikipedia.org/wiki/Stemming

# %%
stemmer = nltk.stem.SnowballStemmer("english")

# %%
stemmer.stem("car")
# Out:
# 'car'

# %%
stemmer.stem("cars")
# Out:
# 'car'

# %%
stemmer.stem("say")
# Out:
# 'say'

# %%
stemmer.stem("saying")
# Out:
# 'say'

# %%
stemmer.stem("said")
# Out:
# 'said'

# %%
[(word, stemmer.stem(word)) for word in words]
# Out:
# [('Some', 'some'),
#  ('people', 'peopl'),
#  ('did', 'did'),
#  ('not', 'not'),
#  ('think', 'think'),
#  ('it', 'it'),
#  ('was', 'was'),
#  ('possible', 'possibl'),
#  ('to', 'to'),
#  ('produce', 'produc'),
#  ('a', 'a'),
#  ('#', '#'),
#  ('COVID19', 'covid19'),
#  ('vaccine', 'vaccin'),
#  ('so', 'so'),
#  ('quickly', 'quick'),
#  (',', ','),
#  ('but', 'but'),
#  ('it', 'it'),
#  ('was', 'was'),
#  ('.', '.'),
#  ('Now', 'now'),
#  ('some', 'some'),
#  ('people', 'peopl'),
#  ('say', 'say'),
#  ('that', 'that'),
#  ('vaccinating', 'vaccin'),
#  ('the', 'the'),
#  ('world', 'world'),
#  ('is', 'is'),
#  ('not', 'not'),
#  ('possible', 'possibl'),
#  ('.', '.'),
#  ('They', 'they'),
#  ('’', '’'),
#  ('re', 're'),
#  ('wrong', 'wrong'),
#  ('.', '.'),
#  ('As', 'as'),
#  ('Nelson', 'nelson'),
#  ('Mandela', 'mandela'),
#  (',', ','),
#  ('Madiba', 'madiba'),
#  (',', ','),
#  ('said', 'said'),
#  (';', ';'),
#  ('it', 'it'),
#  ('always', 'alway'),
#  ('seems', 'seem'),
#  ('impossible', 'imposs'),
#  ('until', 'until'),
#  ('it', 'it'),
#  ('’', '’'),
#  ('s', 's'),
#  ('done', 'done'),
#  ('.', '.')]

# %% [markdown]
# ### N-grams

# %% [markdown]
# An n-gram is a contiguous sequence of n items from a given sample of text or speech. The items can be phonemes, syllables, letters, words or base pairs according to the application.
#
# Using Latin numerical prefixes, an n-gram of size 1 is referred to as a "unigram"; size 2 is a "bigram"; size 3 is a "trigram".

# %% [markdown]
# N-gram on Wikipedia: https://en.wikipedia.org/wiki/N-gram

# %%
from IPython.display import Image
Image(f"{classdata_folder}/images/ngram.png")

# %% [markdown]
# N-gram models are known to be effective in capturing phrases of multiple words.

# %%
from nltk.util import ngrams

# %%
ngrams(words, 1)

# %%
list(ngrams(words, 1))
# Out:
# [('Some',),
#  ('people',),
#  ('did',),
#  ('not',),
#  ('think',),
#  ('it',),
#  ('was',),
#  ('possible',),
#  ('to',),
#  ('produce',),
#  ('a',),
#  ('#',),
#  ('COVID19',),
#  ('vaccine',),
#  ('so',),
#  ('quickly',),
#  (',',),
#  ('but',),
#  ('it',),
#  ('was',),
#  ('.',),
#  ('Now',),
#  ('some',),
#  ('people',),
#  ('say',),
#  ('that',),
#  ('vaccinating',),
#  ('the',),
#  ('world',),
#  ('is',),
#  ('not',),
#  ('possible',),
#  ('.',),
#  ('They',),
#  ('’',),
#  ('re',),
#  ('wrong',),
#  ('.',),
#  ('As',),
#  ('Nelson',),
#  ('Mandela',),
#  (',',),
#  ('Madiba',),
#  (',',),
#  ('said',),
#  (';',),
#  ('it',),
#  ('always',),
#  ('seems',),
#  ('impossible',),
#  ('until',),
#  ('it',),
#  ('’',),
#  ('s',),
#  ('done',),
#  ('.',)]

# %% [markdown]
# Unigrams are practically the same as word tokens.

# %%
list(ngrams(words, 2))
# Out:
# [('Some', 'people'),
#  ('people', 'did'),
#  ('did', 'not'),
#  ('not', 'think'),
#  ('think', 'it'),
#  ('it', 'was'),
#  ('was', 'possible'),
#  ('possible', 'to'),
#  ('to', 'produce'),
#  ('produce', 'a'),
#  ('a', '#'),
#  ('#', 'COVID19'),
#  ('COVID19', 'vaccine'),
#  ('vaccine', 'so'),
#  ('so', 'quickly'),
#  ('quickly', ','),
#  (',', 'but'),
#  ('but', 'it'),
#  ('it', 'was'),
#  ('was', '.'),
#  ('.', 'Now'),
#  ('Now', 'some'),
#  ('some', 'people'),
#  ('people', 'say'),
#  ('say', 'that'),
#  ('that', 'vaccinating'),
#  ('vaccinating', 'the'),
#  ('the', 'world'),
#  ('world', 'is'),
#  ('is', 'not'),
#  ('not', 'possible'),
#  ('possible', '.'),
#  ('.', 'They'),
#  ('They', '’'),
#  ('’', 're'),
#  ('re', 'wrong'),
#  ('wrong', '.'),
#  ('.', 'As'),
#  ('As', 'Nelson'),
#  ('Nelson', 'Mandela'),
#  ('Mandela', ','),
#  (',', 'Madiba'),
#  ('Madiba', ','),
#  (',', 'said'),
#  ('said', ';'),
#  (';', 'it'),
#  ('it', 'always'),
#  ('always', 'seems'),
#  ('seems', 'impossible'),
#  ('impossible', 'until'),
#  ('until', 'it'),
#  ('it', '’'),
#  ('’', 's'),
#  ('s', 'done'),
#  ('done', '.')]

# %%
[" ".join(gram) for gram in ngrams(words, 2)]
# Out:
# ['Some people',
#  'people did',
#  'did not',
#  'not think',
#  'think it',
#  'it was',
#  'was possible',
#  'possible to',
#  'to produce',
#  'produce a',
#  'a #',
#  '# COVID19',
#  'COVID19 vaccine',
#  'vaccine so',
#  'so quickly',
#  'quickly ,',
#  ', but',
#  'but it',
#  'it was',
#  'was .',
#  '. Now',
#  'Now some',
#  'some people',
#  'people say',
#  'say that',
#  'that vaccinating',
#  'vaccinating the',
#  'the world',
#  'world is',
#  'is not',
#  'not possible',
#  'possible .',
#  '. They',
#  'They ’',
#  '’ re',
#  're wrong',
#  'wrong .',
#  '. As',
#  'As Nelson',
#  'Nelson Mandela',
#  'Mandela ,',
#  ', Madiba',
#  'Madiba ,',
#  ', said',
#  'said ;',
#  '; it',
#  'it always',
#  'always seems',
#  'seems impossible',
#  'impossible until',
#  'until it',
#  'it ’',
#  '’ s',
#  's done',
#  'done .']

# %%
[" ".join(gram) for gram in ngrams(words, 3)]
# Out:
# ['Some people did',
#  'people did not',
#  'did not think',
#  'not think it',
#  'think it was',
#  'it was possible',
#  'was possible to',
#  'possible to produce',
#  'to produce a',
#  'produce a #',
#  'a # COVID19',
#  '# COVID19 vaccine',
#  'COVID19 vaccine so',
#  'vaccine so quickly',
#  'so quickly ,',
#  'quickly , but',
#  ', but it',
#  'but it was',
#  'it was .',
#  'was . Now',
#  '. Now some',
#  'Now some people',
#  'some people say',
#  'people say that',
#  'say that vaccinating',
#  'that vaccinating the',
#  'vaccinating the world',
#  'the world is',
#  'world is not',
#  'is not possible',
#  'not possible .',
#  'possible . They',
#  '. They ’',
#  'They ’ re',
#  '’ re wrong',
#  're wrong .',
#  'wrong . As',
#  '. As Nelson',
#  'As Nelson Mandela',
#  'Nelson Mandela ,',
#  'Mandela , Madiba',
#  ', Madiba ,',
#  'Madiba , said',
#  ', said ;',
#  'said ; it',
#  '; it always',
#  'it always seems',
#  'always seems impossible',
#  'seems impossible until',
#  'impossible until it',
#  'until it ’',
#  'it ’ s',
#  '’ s done',
#  's done .']

# %% [markdown]
# Note that while n-grams are able to capture meaningful phrases in text, they may generate much noise.

# %% [markdown]
# ## NLP Techniques Using TextBlob

# %% [markdown]
# TextBlob: https://textblob.readthedocs.io/

# %%
from textblob import TextBlob

# %% [markdown]
# ### Sentiment Analysis

# %%
Image(f"{classdata_folder}/images/sentiment_analysis.png")

# %%
text = "It's just awesome!"

# %%
tb = TextBlob(text)

# %%
tb.sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
tb.sentiment.polarity
# Out:
# 1.0

# %%
tb.sentiment.subjectivity
# Out:
# 1.0

# %%
text = "It's Friday."

# %%
tb = TextBlob(text)
tb.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
text = "I hate you ~!~!~! haha :)"
tb = TextBlob(text)
tb.sentiment
# Out:
# Sentiment(polarity=-0.10000000000000002, subjectivity=0.7333333333333334)

# %% [markdown]
# ## Loading Data

# %%
# urls = ["https://fivethirtyeight.com/features/"]

# for i in range(2, 151):
#     url = f"https://fivethirtyeight.com/features/page/{i}/"
#     urls.append(url)

# import requests
# from bs4 import BeautifulSoup
# import time

# for url in urls:
#     print(url)

#     ####################################################
#     # Get the content of a page
#     ####################################################
#     r = requests.get(url)
#     soup = BeautifulSoup(r.content, "html.parser")

#     ####################################################
#     # Get the list of articles
#     ####################################################
#     h2_list = soup.find_all("h2", {"class": "article-title entry-title"})

#     for h2 in h2_list:
#         ####################################################
#         # Find the anchor tag
#         ####################################################
#         a = h2.find("a")

#         ####################################################
#         # Extract the title & URL of an article
#         ####################################################
#         title = a.text
#         article_url = a["href"]

#         ####################################################
#         # Fetch the content and save it as an HTML file
#         ####################################################
#         print("- " + article_url + ": processing...")

#         r2 = requests.get(article_url)

#         if "/features/" in article_url:
#           file_name = article_url[len("https://fivethirtyeight.com/features/"):-1] + ".html"
#         elif "/videos/" in article_url:
#           file_name = article_url[len("https://fivethirtyeight.com/videos/"):-1] + ".html"
#         elif "/methodology/" in article_url:
#           file_name = article_url[len("https://fivethirtyeight.com/methodology/"):-1] + ".html"
#         elif "/live-blog/" in article_url:
#           file_name = article_url[len("https://fivethirtyeight.com/live-blog/"):-1] + ".html"
#         else:
#           assert 0 == 1, "Unknown article url pattern!"

#         with open(f"{outcome_folder}/HTMLs/{file_name}", "w+b") as fw:
#             fw.write(r2.content)

#         print("- " + file_name + ": saved.")

#         ####################################################
#         # Sleep for a second to not overload the web site
#         ####################################################
#         time.sleep(1)

#     print()

# %%
# import os
# from bs4 import BeautifulSoup

# html_files = [file for file in os.listdir(f"{outcome_folder}/HTMLs") if file.endswith(".html")]

# with open(f"{outcome_folder}/html_data.csv", "w") as fw:
#     ####################################################
#     # Column names on the first row
#     ####################################################
#     fw.write("file_name\ttitle\tauthor\tdatetime\tbody\n")

#     for file_name in html_files:
#         ####################################################
#         # Column values starting from the second row
#         ####################################################
#         with open(f"{outcome_folder}/HTMLs/{file_name}", "r+b") as fr:
#             print(file_name)
#             soup = BeautifulSoup(fr.read(), "html.parser")

#             ####################################################
#             # No title exception handling
#             ####################################################
#             if soup.find("h1", {"class": "article-title article-title-single entry-title"}) == None:
#                 continue
#             else:
#                 article_title = soup.find("h1", {"class": "article-title article-title-single entry-title"}).text

#             ####################################################
#             # No author exception handling
#             ####################################################
#             if soup.find("a", {"class": "author url fn"}) == None:
#                 article_author = ""
#             else:
#                 article_author = soup.find("a", {"class": "author url fn"}).text

#             ####################################################
#             # No datetime exception handling
#             ####################################################
#             if soup.find("time", {"class": "datetime"}) == None:
#                 article_datetime = ""
#             else:
#                 article_datetime = soup.find("time", {"class": "datetime"}).text

#             article_body = soup.find("div", attrs={"class": "entry-content single-post-content"}).text

#             ####################################################
#             # Remove all possible new lines and tabs
#             ####################################################
#             article_title = article_title.replace("\n", " ").replace("\t", " ")
#             article_aurthor = article_author.replace("\n", " ").replace("\t", " ")
#             article_datetime = article_datetime.replace("\n", " ").replace("\t", " ")
#             article_body = article_body.replace("\n", " ").replace("\t", " ")

#             fw.write(f"{file_name}\t{article_title}\t{article_author}\t{article_datetime}\t{article_body}\n")

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 150)

df = pd.read_csv(f"{classdata_folder}/html_data.csv", sep="\t")
df
# Out:
#                                                                                                     file_name  \
# 0                                                                                 house-retirements-2024.html
# 1                                                         americans-increasingly-against-abortion-limits.html
# 2                                                        who-would-win-if-trump-wasnt-in-the-gop-primary.html
# 3                                                                                     2024-dropout-draft.html
# 4                                                                republican-august-debate-qualifications.html
# ...                                                                                                       ...
# 1345                       new-yorks-gerrymander-might-change-which-party-picks-up-seats-in-the-midterms.html
# 1346                                                     nfl-teams-are-making-brian-floress-case-for-him.html
# 1347                                              russian-doping-isnt-the-only-problem-in-figure-skating.html
# 1348                        giannis-antetokounmpo-is-committing-fewer-charges-but-hes-just-as-aggressive.html
# %%
counter = Counter()          # The counter object will have all the word count information

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()  # Convert all words to lowercase
        word_set.add(word)

    counter.update(word_set) # Be aware of the indentation!

# %% [markdown]
# Note that you converted each word to lowercase to avoid any potential variations due to the case sensitivity.

# %% [markdown]
# Note also that you used a set to remove duplicate words in a tweet. This allows you to count each word in a tweet as just 1, even if it appears more than once in the tweet.

# %%
from IPython.display import Image
Image(f"{classdata_folder}/images/word_count.png")

# %%
counter.most_common(50)   # Show the top-n most popular words in counter
# Out:
# [('the', 718),
#  ('?', 381),
#  ('’', 308),
#  ('to', 277),
#  ('in', 237),
#  ('a', 203),
#  ('is', 201),
#  ('s', 189),
#  ('are', 174),
#  ('.', 169),
#  ('for', 168),
#  ('and', 164),
#  ('of', 144),
#  ('how', 142),
#  ('can', 124),
#  ("'s", 113),
#  ('why', 109),
#  ('what', 107),
#  ('you', 102),
#  (',', 101),
#  ('it', 100),
#  ('americans', 94),
#  ('this', 88),
#  ('—', 88),
#  ('will', 86),
#  ('we', 85),
#  ('could', 78),
#  ('about', 77),
#  ('t', 76),
#  ('that', 75),
#  ('on', 71),
#  ('trump', 70),
#  ('democrats', 67),
#  ('be', 64),
#  ('abortion', 63),
#  ('win', 62),
#  ('have', 60),
#  ('but', 60),
#  ('do', 58),
#  ('their', 55),
#  ("n't", 53),
#  ('biden', 52),
#  ('election', 52),
#  ('senate', 52),
#  ('new', 51),
#  ('republicans', 49),
#  ('more', 49),
#  ('2024', 48),
#  ('who', 46),
#  ('at', 43)]

# %% [markdown]
# collections.Counter.most_common: https://docs.python.org/3/library/collections.html#collections.Counter.most_common

# %% [markdown]
# Stopwords are words that are filtered out before processing of natural language text. Stopwords are generally the most common words in a language. There is no single universal list of stopwords used by all natural language processing tools, and indeed not all tools even use such a list. Some tools avoid removing stop words to support phrase search.

# %% [markdown]
# Stopwords on Wikipedia: https://en.wikipedia.org/wiki/Stop_words

# %%
from nltk.corpus import stopwords

# %%
global_stopwords = stopwords.words("english")
global_stopwords[:50]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be']

# %% [markdown]
# Stopwords, in fact, have no meaning in terms of keyword analysis.

# %%
counter = Counter()

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()

        if word not in global_stopwords:   # Check if the word is a stopword
            word_set.add(word)

    counter.update(word_set)

counter.most_common(30)
# Out:
# [('?', 381),
#  ('’', 308),
#  ('.', 169),
#  ("'s", 113),
#  (',', 101),
#  ('americans', 94),
#  ('—', 88),
#  ('could', 78),
#  ('trump', 70),
#  ('democrats', 67),
#  ('abortion', 63),
#  ('win', 62),
#  ("n't", 53),
#  ('biden', 52),
#  ('election', 52),
#  ('senate', 52),
#  ('new', 51),
#  ('republicans', 49),
#  ('2024', 48),
#  ('republican', 41),
#  ('voters', 41),
#  ('court', 37),
#  ('2022', 37),
#  ('primary', 36),
#  ('supreme', 36),
#  ('week', 36),
#  ('might', 35),
#  ('change', 35),
#  ("'", 34),
#  ('year', 33)]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
local_stopwords = [c for c in string.punctuation] +\
                  ['‘', '’', '—', '…', "'re", "'s", 'could', "n't", ]
local_stopwords
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  '‘',
#  '’',
#  '—',
#  '…',
#  "'re",
#  "'s",
#  'could',
#  "n't"]

# %% [markdown]
# Note that the words *health*, *mental*, and *mentalhealth* were included in the local stopwords, as they are search terms so every tweet must have any of those words, which makes them not so meaningful in terms of keyword analysis.

# %%
counter = Counter()

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()

        if word not in (global_stopwords + local_stopwords):
        # Check if the word is either a global or a local stopword
            word_set.add(word)

    counter.update(word_set)

counter.most_common(30)
# Out:
# [('americans', 94),
#  ('trump', 70),
#  ('democrats', 67),
#  ('abortion', 63),
#  ('win', 62),
#  ('biden', 52),
#  ('election', 52),
#  ('senate', 52),
#  ('new', 51),
#  ('republicans', 49),
#  ('2024', 48),
#  ('republican', 41),
#  ('voters', 41),
#  ('court', 37),
#  ('2022', 37),
#  ('primary', 36),
#  ('supreme', 36),
#  ('week', 36),
#  ('might', 35),
#  ('change', 35),
#  ('year', 33),
#  ('want', 33),
#  ('nba', 33),
#  ('gop', 32),
#  ('watch', 32),
#  ('looking', 31),
#  ('house', 28),
#  ('georgia', 28),
#  ('datasets', 28),
#  ('states', 27)]

# %%
counter["trump"]
# Out:
# 70

# %% [markdown]
# The word '*trump*' appears 150 times in the corpus.

# %%
[(word, count) for word, count in counter.items() if count > 50]
# Out:
# [('abortion', 63),
#  ('americans', 94),
#  ('trump', 70),
#  ('win', 62),
#  ('biden', 52),
#  ('election', 52),
#  ('new', 51),
#  ('senate', 52),
#  ('democrats', 67)]

# %% [markdown]
# ### Popular Nouns

# %%
counter1 = Counter()

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()
        tag = t[1]

        if tag.startswith("NN") & (word not in (global_stopwords + local_stopwords)):
            word_set.add(word)

    counter1.update(word_set)

counter1.most_common(30)
# Out:
# [('americans', 94),
#  ('trump', 67),
#  ('democrats', 65),
#  ('abortion', 63),
#  ('biden', 52),
#  ('senate', 52),
#  ('election', 51),
#  ('new', 51),
#  ('republicans', 49),
#  ('voters', 41),
#  ('court', 37),
#  ('supreme', 36),
#  ('primary', 35),
#  ('win', 35),
#  ('week', 34),
#  ('year', 33),
#  ('gop', 32),
#  ('might', 32),
#  ('change', 31),
#  ('nba', 31),
#  ('republican', 30),
#  ('house', 28),
#  ('georgia', 28),
#  ('datasets', 28),
#  ('states', 27),
#  ('candidates', 25),
#  ('world', 25),
#  ('midterms', 25),
#  ('state', 23),
#  ('mlb', 23)]

# %% [markdown]
# ### Popular Adjectives

# %%
counter2 = Counter()

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()
        tag = t[1]

        if tag.startswith("JJ") & (word not in (global_stopwords + local_stopwords)):
            word_set.add(word)

    counter2.update(word_set)

counter2.most_common(30)
# Out:
# [('last', 14),
#  ('many', 13),
#  ('much', 12),
#  ('democratic', 12),
#  ('republican', 11),
#  ('american', 10),
#  ('political', 8),
#  ('presidential', 5),
#  ('special', 5),
#  ('final', 5),
#  ('early', 4),
#  ('unpopular', 4),
#  ('conservative', 4),
#  ('red', 4),
#  ('big', 4),
#  ('best', 4),
#  ('unlikely', 4),
#  ('2022-23', 4),
#  ('congressional', 3),
#  ('vulnerable', 3),
#  ('major', 3),
#  ('important', 3),
#  ('concerned', 3),
#  ('good', 3),
#  ('asian', 3),
#  ('likely', 3),
#  ('next', 3),
#  ('ready', 3),
#  ('real', 3),
#  ('third-party', 2)]

# %% [markdown]
# ### Popular Verbs

# %%
counter3 = Counter()

for l in df.tagged_words:
    word_set = set()

    for t in l:
        word = t[0].lower()
        tag = t[1]

        if tag.startswith("VB") & (word not in (global_stopwords + local_stopwords)):
            word_set.add(word)

    counter3.update(word_set)

counter3.most_common(30)
# Out:
# [('looking', 30),
#  ('watch', 28),
#  ('win', 26),
#  ('want', 23),
#  ('need', 20),
#  ('know', 17),
#  ('think', 16),
#  ('make', 16),
#  ('buy', 16),
#  ('going', 10),
#  ('hiring', 10),
#  ('making', 8),
#  ('believe', 8),
#  ('winning', 8),
#  ('turned', 7),
#  ('take', 7),
#  ('trying', 7),
#  ('get', 7),
#  ('made', 6),
#  ('vote', 6),
#  ('getting', 6),
#  ('happens', 6),
#  ('keep', 6),
#  ('thinking', 6),
#  ('voted', 6),
#  ('favored', 6),
#  ('feel', 6),
#  ('expect', 6),
#  ('polling', 5),
#  ('running', 5)]

# %% [markdown]
# ## Putting Everything Together into a Single Function

# %%
def get_counter(dataframe, stopwords=[], target_tag=None):
    counter = Counter()

    for l in dataframe.tagged_words:
        word_set = set()

        for t in l:
            word = t[0].lower()
            tag = t[1]

            ##########################################################
            # Check if the word is a stopword.
            ##########################################################
            if word in stopwords:
                continue

            if target_tag is None:
                word_set.add(word)
            else:
                ##########################################################
                # Check the tag
                ##########################################################
                if tag.startswith(target_tag):
                    word_set.add(word)
                else:
                    continue

        counter.update(word_set)     # Be aware of the indentation!

    return counter

# %%
counter_all = get_counter(df, global_stopwords+local_stopwords)
counter_all.most_common(30)
# Out:
# [('americans', 94),
#  ('trump', 70),
#  ('democrats', 67),
#  ('abortion', 63),
#  ('win', 62),
#  ('biden', 52),
#  ('election', 52),
#  ('senate', 52),
#  ('new', 51),
#  ('republicans', 49),
#  ('2024', 48),
#  ('republican', 41),
#  ('voters', 41),
#  ('court', 37),
#  ('2022', 37),
#  ('primary', 36),
#  ('supreme', 36),
#  ('week', 36),
#  ('might', 35),
#  ('change', 35),
#  ('year', 33),
#  ('want', 33),
#  ('nba', 33),
#  ('gop', 32),
#  ('watch', 32),
#  ('looking', 31),
#  ('house', 28),
#  ('georgia', 28),
#  ('datasets', 28),
#  ('states', 27)]

# %%
counter_adj = get_counter(df, global_stopwords+local_stopwords, "JJ")
counter_adj.most_common(30)
# Out:
# [('last', 14),
#  ('many', 13),
#  ('much', 12),
#  ('democratic', 12),
#  ('republican', 11),
#  ('american', 10),
#  ('political', 8),
#  ('presidential', 5),
#  ('special', 5),
#  ('final', 5),
#  ('early', 4),
#  ('unpopular', 4),
#  ('conservative', 4),
#  ('red', 4),
#  ('big', 4),
#  ('best', 4),
#  ('unlikely', 4),
#  ('2022-23', 4),
#  ('congressional', 3),
#  ('vulnerable', 3),
#  ('major', 3),
#  ('important', 3),
#  ('concerned', 3),
#  ('good', 3),
#  ('asian', 3),
#  ('likely', 3),
#  ('next', 3),
#  ('ready', 3),
#  ('real', 3),
#  ('third-party', 2)]

# %% [markdown]
# ## Create Time Series Data

# %%
count = pd.Series(data=1, index=df.datetime).resample(rule="w").count()
count
# Out:
# datetime
# 2022-02-20    12
# 2022-02-27    19
# 2022-03-06    26
# 2022-03-13    20
# 2022-03-20    16
#               ..
# 2023-07-16     6
# 2023-07-23     7
# 2023-07-30     7
# 2023-08-06     8
# 2023-08-13     8
# Length: 78, dtype: int64

# %% [markdown]
# The `rule` argument value takes
# - "h": hourly
# - "d": daily
# - "w": weekly
# - "m": monthly
# - "y": yearly

# %%
count.max(), count.idxmax()
# Out:
# (34, Timestamp('2022-11-06 00:00:00'))

# %%
count.min(), count.idxmin()
# Out:
# (3, Timestamp('2022-11-27 00:00:00'))

# %%
df[(df.datetime >= "2022-10-31") & (df.datetime < "2022-11-07")]
# Out:
#                                                                                     file_name  \
# 541                 control-of-the-senate-could-rest-on-abortion-and-inflation-in-nevada.html
# 542                                           dusty-bakers-astros-didnt-need-an-asterisk.html
# 543           the-phillies-will-need-the-long-ball-for-a-long-shot-world-series-comeback.html
# 544                      republicans-are-doing-notably-well-in-these-two-governors-races.html
# 545                         how-the-two-parties-are-making-their-final-pitches-to-voters.html
# 546                                 the-case-for-a-democratic-surprise-on-election-night.html
# 547                  all-you-need-to-know-about-pennsylvanias-senate-race-through-tv-ads.html
# 548                        dejounte-murray-looks-like-the-running-mate-trae-young-needed.html
# 549                                                       when-will-the-fall-colors-peak.html
# 550                           what-happens-when-kids-have-access-to-nba-level-technology.html
# 551          why-republicans-are-trying-to-flip-more-southern-california-house-districts.html
# 552                                        what-americans-think-about-political-violence.html
# 553                     all-you-need-to-know-about-wisconsins-senate-race-through-tv-ads.html
# 554                                 american-turning-point-abortion-rights-on-the-ballot.html
# 555                                                                   2022-polling-error.html
# 556                          what-happens-if-georgias-senate-race-goes-to-a-runoff-again.html
# 557     tom-brady-used-to-put-the-team-on-his-back-now-he-needs-help-and-isnt-getting-it.html
# 558                                   how-do-all-these-republican-polls-affect-the-model.html
# 559                       all-you-need-to-know-about-georgias-senate-race-through-tv-ads.html
# 560                                   russell-wilson-misses-tyler-lockett-and-dk-metcalf.html
# 561                                            the-datasets-were-looking-at-this-week-25.html
# 562                                    the-case-for-a-republican-sweep-on-election-night.html
# 563                     the-republican-path-to-a-house-majority-goes-through-the-suburbs.html
# 564                                 how-5-voters-of-color-are-thinking-about-the-economy.html
# 565                                                       where-stacey-abrams-went-wrong.html
# 566                                   americans-are-still-most-concerned-about-inflation.html
# 567                             how-voters-are-reacting-to-fettermans-debate-performance.html
# 548                                         [Dejounte, Murray, Looks, Like, The, Running, Mate, Trae, Young, Needed]
# 549                                                                         [When, Will, The, Fall, Colors, Peak, ?]
# 550                                          [What, Happens, When, Kids, Have, Access, To, NBA-Level, Technology, ?]
# 551                          [Why, Republicans, Are, Trying, To, Flip, More, Southern, California, House, Districts]
# 552                                                             [What, Americans, Think, About, Political, Violence]
# 553                            [All, You, Need, To, Know, About, Wisconsin, ’, s, Senate, Race, ,, Through, TV, Ads]
# 554                                                 [American, Turning, Point, :, Abortion, Rights, On, The, Ballot]
# 555                [Republicans, Are, Just, A, Normal, Polling, Error, Away, From, A, Landslide, —, Or, Wiping, Out]
# 556                               [What, Happens, If, Georgia, ’, s, Senate, Race, Goes, To, A, Runoff, —, Again, ?]
# 557  [Tom, Brady, Used, To, Put, The, Team, On, His, Back, ., Now, He, Needs, Help, —, And, Is, n't, Getting, It, .]
# 558                                                  [How, Do, All, These, Republican, Polls, Affect, The, Model, ?]
# 559                              [All, You, Need, To, Know, About, Georgia, ’, s, Senate, Race, ,, Through, TV, Ads]
# 560                                                      [Russell, Wilson, Misses, Tyler, Lockett, And, DK, Metcalf]
# 561                                                                [The, Datasets, We, 're, Looking, At, This, Week]
# 562                                                      [The, Case, For, A, Republican, Sweep, On, Election, Night]
# 563                                     [The, Republican, Path, To, A, House, Majority, Goes, Through, The, Suburbs]
# 564                                                  [How, 5, Voters, Of, Color, Are, Thinking, About, The, Economy]
# 565                                                                             [Where, Stacey, Abrams, Went, Wrong]
# 566                                                       [Americans, Are, Still, Most, Concerned, About, Inflation]
# 567                                           [How, Voters, Are, Reacting, To, Fetterman, ’, s, Debate, Performance]
# 568                                          [Voters, Will, Decide, The, Future, Of, Abortion, Rights, In, Michigan]
# 569                        [As, States, Banned, Abortion, ,, Thousands, More, Americans, Got, Pills, Online, Anyway]
# 570                                             [Meet, The, Midterm, Candidates, Who, Attended, The, Jan., 6, Rally]
# 571                                          [Short, Passes, Are, All, The, Rage, In, College, Football, This, Year]
# 572                                                                   [The, No-Fun, League, Almost, Ruined, Week, 8]
# 573               [The, Astros, And, Phillies, Have, Showed, Off, Their, Championship, DNA, In, This, World, Series]
# 574                                                                          [What, Happened, To, Stacey, Abrams, ?]
#
#                                                                                                                                               tagged_words
# 541  [(Control, NN), (Of, IN), (The, DT), (Senate, NNP), (Could, NNP), (Rest, NNP), (On, IN), (Abortion, NNP), (And, CC), (Inflation, NNP), (In, IN), (...
# 542                                    [(Dusty, NNP), (Baker, NNP), ('s, POS), (Astros, NNP), (Did, NNP), (n't, RB), (Need, VB), (An, DT), (Asterisk, NN)]
# 543  [(The, DT), (Phillies, NNPS), (Will, NNP), (Need, VB), (The, DT), (Long, NNP), (Ball, NNP), (For, IN), (A, NNP), (Long, NNP), (Shot, NNP), (World,...
# 544           [(Republicans, NNPS), (Are, VBP), (Doing, VBG), (Notably, RB), (Well, RB), (In, IN), (These, DT), (Two, CD), (Governors, NNS), (Races, NNS)]
# 563    [(The, DT), (Republican, JJ), (Path, NNP), (To, TO), (A, NNP), (House, NNP), (Majority, NN), (Goes, NNP), (Through, IN), (The, DT), (Suburbs, NNP)]
# 564                       [(How, WRB), (5, CD), (Voters, NNS), (Of, IN), (Color, NNP), (Are, NNP), (Thinking, VBG), (About, IN), (The, DT), (Economy, NN)]
# 565                                                                                [(Where, WRB), (Stacey, NNP), (Abrams, NNP), (Went, NNP), (Wrong, NNP)]
# 566                                               [(Americans, NNPS), (Are, VBP), (Still, RB), (Most, NNP), (Concerned, JJ), (About, IN), (Inflation, NN)]
# 567              [(How, WRB), (Voters, NNS), (Are, VBP), (Reacting, VBG), (To, TO), (Fetterman, NNP), (’, NNP), (s, JJ), (Debate, NNP), (Performance, NN)]
# 568             [(Voters, NNS), (Will, NNP), (Decide, NNP), (The, DT), (Future, NNP), (Of, IN), (Abortion, NNP), (Rights, NNP), (In, IN), (Michigan, NNP)]
# 569  [(As, IN), (States, NNS), (Banned, VBN), (Abortion, NNP), (,, ,), (Thousands, NNP), (More, RBR), (Americans, NNPS), (Got, NNP), (Pills, NNP), (Onl...
# 570               [(Meet, NNP), (The, DT), (Midterm, NNP), (Candidates, NNPS), (Who, NNP), (Attended, VBD), (The, DT), (Jan., NNP), (6, CD), (Rally, NNP)]
# 571        [(Short, JJ), (Passes, NNS), (Are, VBP), (All, PDT), (The, DT), (Rage, NNP), (In, IN), (College, NNP), (Football, NNP), (This, DT), (Year, NN)]
# 572                                                          [(The, DT), (No-Fun, NNP), (League, NNP), (Almost, NNP), (Ruined, VBD), (Week, NNP), (8, CD)]
# 573  [(The, DT), (Astros, NNP), (And, CC), (Phillies, NNS), (Have, VBP), (Showed, VBN), (Off, IN), (Their, PRP$), (Championship, NNP), (DNA, NN), (In, ...
# 574                                                                          [(What, WP), (Happened, VBD), (To, TO), (Stacey, NNP), (Abrams, NNP), (?, .)]

# %%
len(df[(df.datetime >= "2022-10-31") & (df.datetime < "2022-11-07")])
# Out:
# 34

# %%
counter = get_counter(df[(df.datetime >= "2022-10-31") & (df.datetime < "2022-11-07")], global_stopwords+local_stopwords)
counter.most_common(30)
# Out:
# [('senate', 5),
#  ('need', 5),
#  ('abortion', 4),
#  ('voters', 4),
#  ('race', 4),
#  ('republicans', 3),
#  ('tv', 3),
#  ('ads', 3),
#  ('know', 3),
#  ('americans', 3),
#  ('republican', 3),
#  ('inflation', 2),
#  ('astros', 2),
#  ('phillies', 2),
#  ('world', 2),
#  ('series', 2),
#  ('two', 2),
#  ('election', 2),
#  ('case', 2),
#  ('night', 2),
#  ('happens', 2),
#  ('house', 2),
#  ('rights', 2),
#  ('goes', 2),
#  ('georgia', 2),
#  ('week', 2),
#  ('abrams', 2),
#  ('stacey', 2),
#  ('control', 1),
#  ('nevada', 1)]

# %% [markdown]
# ## Word Clouds

# %%
! pip install --user wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", max_words=100, width=800, height=500)
wc.generate_from_frequencies(counter)
wc.to_file(f"{outcome_folder}/wordcloud.png")
Image(filename=f"{outcome_folder}/wordcloud.png")
